# %%
 import nltk
 nltk.download('punkt')
 nltk.download('wordnet')
# Out:
# [nltk_data] Downloading package punkt to /root/nltk_data...
# [nltk_data]   Package punkt is already up-to-date!
# [nltk_data] Downloading package wordnet to /root/nltk_data...
# True

# %%
import random
import json
import pickle
import numpy as np
import tensorflow as tf

import nltk
from nltk.stem import WordNetLemmatizer

lemmatizer = WordNetLemmatizer()

intents = json.loads(open('/content/intents.json').read())

words = []
classes = []
documents = []
ignoreLetters = ['?', '!', '.', ',']

for intent in intents['intents']:
    for pattern in intent['patterns']:
        wordList = nltk.word_tokenize(pattern)
        words.extend(wordList)
        documents.append((wordList, intent['tag']))
        if intent['tag'] not in classes:
            classes.append(intent['tag'])

words = [lemmatizer.lemmatize(word) for word in words if word not in ignoreLetters]
words = sorted(set(words))

classes = sorted(set(classes))

pickle.dump(words, open('words.pkl', 'wb'))
pickle.dump(classes, open('classes.pkl', 'wb'))

training = []
outputEmpty = [0] * len(classes)

for document in documents:
    bag = []
    wordPatterns = document[0]
    wordPatterns = [lemmatizer.lemmatize(word.lower()) for word in wordPatterns]
    for word in words:
        bag.append(1) if word in wordPatterns else bag.append(0)

    outputRow = list(outputEmpty)
    outputRow[classes.index(document[1])] = 1
    training.append(bag + outputRow)

random.shuffle(training)
training = np.array(training)

trainX = training[:, :len(words)]
trainY = training[:, len(words):]


model = tf.keras.Sequential()
model.add(tf.keras.layers.Dense(128, input_shape=(len(trainX[0]),), activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(64, activation = 'relu'))
model.add(tf.keras.layers.Dropout(0.5))
model.add(tf.keras.layers.Dense(len(trainY[0]), activation='softmax'))

sgd = tf.keras.optimizers.SGD(learning_rate=0.01, momentum=0.9, nesterov=True)
model.compile(loss='categorical_crossentropy', optimizer=sgd, metrics=['accuracy'])

hist = model.fit(np.array(trainX), np.array(trainY), epochs=200, batch_size=5, verbose=1)
model.save('chatbot_model.h5', hist)
print('Done')
# Out:
# Epoch 1/200
# 4/4 [==============================] - 1s 6ms/step - loss: 1.5011 - accuracy: 0.0556
# Epoch 2/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.3855 - accuracy: 0.4444
# Epoch 3/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.3589 - accuracy: 0.4444
# Epoch 4/200
# 4/4 [==============================] - 0s 4ms/step - loss: 1.2880 - accuracy: 0.5556
# Epoch 5/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2682 - accuracy: 0.6111
# Epoch 6/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.2327 - accuracy: 0.5556
# Epoch 7/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1651 - accuracy: 0.4444
# Epoch 8/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1151 - accuracy: 0.6667
# Epoch 9/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1356 - accuracy: 0.5000
# Epoch 10/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.1325 - accuracy: 0.6667
# Epoch 11/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0338 - accuracy: 0.6667
# Epoch 12/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9830 - accuracy: 0.7222
# Epoch 13/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.9729 - accuracy: 0.6667
# Epoch 14/200
# 4/4 [==============================] - 0s 3ms/step - loss: 1.0034 - accuracy: 0.7222
# Epoch 15/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9247 - accuracy: 0.5556
# Epoch 16/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.8931 - accuracy: 0.7778
# Epoch 17/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8493 - accuracy: 0.7778
# Epoch 18/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.8631 - accuracy: 0.7778
# Epoch 19/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.9904 - accuracy: 0.6667
# Epoch 20/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6736 - accuracy: 0.8333
# Epoch 21/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7296 - accuracy: 0.8333
# Epoch 22/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7440 - accuracy: 0.8333
# Epoch 23/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.7543 - accuracy: 0.7778
# Epoch 24/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6748 - accuracy: 0.8333
# Epoch 25/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.6814 - accuracy: 0.7778
# Epoch 26/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.7161 - accuracy: 0.8333
# Epoch 27/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.7359 - accuracy: 0.7778
# Epoch 28/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.6758 - accuracy: 0.8333
# Epoch 29/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5252 - accuracy: 0.8889
# Epoch 30/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5487 - accuracy: 0.8333
# Epoch 31/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5705 - accuracy: 0.8333
# Epoch 32/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5667 - accuracy: 0.8333
# Epoch 33/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5509 - accuracy: 0.7778
# Epoch 34/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.5314 - accuracy: 0.8333
# Epoch 35/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5327 - accuracy: 0.8333
# Epoch 36/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4900 - accuracy: 0.7778
# Epoch 37/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.5515 - accuracy: 0.7778
# Epoch 38/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3943 - accuracy: 0.9444
# Epoch 39/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5901 - accuracy: 0.7222
# Epoch 40/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4820 - accuracy: 0.8333
# Epoch 41/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4678 - accuracy: 0.8333
# Epoch 42/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4421 - accuracy: 0.8889
# Epoch 43/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4686 - accuracy: 0.8333
# Epoch 44/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4449 - accuracy: 0.8333
# Epoch 45/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3702 - accuracy: 0.8333
# Epoch 46/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4711 - accuracy: 0.8889
# Epoch 47/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3574 - accuracy: 0.9444
# Epoch 48/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.5085 - accuracy: 0.8333
# Epoch 49/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4357 - accuracy: 0.8333
# Epoch 50/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3563 - accuracy: 0.9444
# Epoch 51/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4554 - accuracy: 0.7778
# Epoch 52/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2590 - accuracy: 0.9444
# Epoch 53/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.4218 - accuracy: 0.8333
# Epoch 54/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3311 - accuracy: 0.8889
# Epoch 55/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2881 - accuracy: 0.9444
# Epoch 56/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3321 - accuracy: 0.8333
# Epoch 57/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3337 - accuracy: 0.9444
# Epoch 58/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4225 - accuracy: 0.8889
# Epoch 59/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2969 - accuracy: 0.9444
# Epoch 60/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2554 - accuracy: 0.9444
# Epoch 61/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2694 - accuracy: 0.9444
# Epoch 62/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2455 - accuracy: 0.9444
# Epoch 63/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3249 - accuracy: 0.9444
# Epoch 64/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3521 - accuracy: 0.9444
# Epoch 65/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2151 - accuracy: 1.0000
# Epoch 66/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2270 - accuracy: 0.8889
# Epoch 67/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3472 - accuracy: 0.8889
# Epoch 68/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2524 - accuracy: 0.9444
# Epoch 69/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2791 - accuracy: 0.8889
# Epoch 70/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2297 - accuracy: 0.8889
# Epoch 71/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3386 - accuracy: 0.9444
# Epoch 72/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3305 - accuracy: 0.8889
# Epoch 73/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2988 - accuracy: 0.8889
# Epoch 74/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2824 - accuracy: 0.8889
# Epoch 75/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2258 - accuracy: 0.9444
# Epoch 76/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1868 - accuracy: 0.9444
# Epoch 77/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3166 - accuracy: 0.8889
# Epoch 78/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.3497 - accuracy: 0.8889
# Epoch 79/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2090 - accuracy: 0.9444
# Epoch 80/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2323 - accuracy: 0.9444
# Epoch 81/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2828 - accuracy: 0.9444
# Epoch 82/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.3204 - accuracy: 0.8333
# Epoch 83/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2465 - accuracy: 0.9444
# Epoch 84/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2403 - accuracy: 0.8889
# Epoch 85/200
# 4/4 [==============================] - 0s 6ms/step - loss: 0.2264 - accuracy: 0.9444
# Epoch 86/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1876 - accuracy: 0.9444
# Epoch 87/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2536 - accuracy: 0.9444
# Epoch 88/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1869 - accuracy: 0.9444
# Epoch 89/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2598 - accuracy: 0.9444
# Epoch 90/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2653 - accuracy: 0.9444
# Epoch 91/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2319 - accuracy: 0.9444
# Epoch 92/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2286 - accuracy: 0.9444
# Epoch 93/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2198 - accuracy: 0.9444
# Epoch 94/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2513 - accuracy: 0.9444
# Epoch 95/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2480 - accuracy: 0.8889
# Epoch 96/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.4256 - accuracy: 0.8889
# Epoch 97/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2203 - accuracy: 0.9444
# Epoch 98/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2611 - accuracy: 0.8889
# Epoch 99/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2811 - accuracy: 0.9444
# Epoch 100/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2544 - accuracy: 0.8889
# Epoch 101/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1827 - accuracy: 0.9444
# Epoch 102/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2503 - accuracy: 0.9444
# Epoch 103/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2181 - accuracy: 0.9444
# Epoch 104/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2681 - accuracy: 0.9444
# Epoch 105/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2219 - accuracy: 0.9444
# Epoch 106/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2329 - accuracy: 0.8889
# Epoch 107/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1736 - accuracy: 0.9444
# Epoch 108/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1354 - accuracy: 0.9444
# Epoch 109/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1719 - accuracy: 0.9444
# Epoch 110/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1939 - accuracy: 0.9444
# Epoch 111/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2409 - accuracy: 0.9444
# Epoch 112/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1641 - accuracy: 0.9444
# Epoch 113/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1292 - accuracy: 0.9444
# Epoch 114/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1567 - accuracy: 0.9444
# Epoch 115/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2647 - accuracy: 0.8889
# Epoch 116/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2040 - accuracy: 0.9444
# Epoch 117/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1677 - accuracy: 0.9444
# Epoch 118/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2677 - accuracy: 0.9444
# Epoch 119/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1605 - accuracy: 0.9444
# Epoch 120/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2162 - accuracy: 0.9444
# Epoch 121/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1881 - accuracy: 0.8889
# Epoch 122/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1515 - accuracy: 1.0000
# Epoch 123/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2746 - accuracy: 0.8889
# Epoch 124/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2543 - accuracy: 0.9444
# Epoch 125/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2212 - accuracy: 0.8889
# Epoch 126/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2255 - accuracy: 0.9444
# Epoch 127/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1985 - accuracy: 0.9444
# Epoch 128/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1824 - accuracy: 0.9444
# Epoch 129/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2093 - accuracy: 0.9444
# Epoch 130/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2270 - accuracy: 0.9444
# Epoch 131/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1782 - accuracy: 0.9444
# Epoch 132/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2335 - accuracy: 0.9444
# Epoch 133/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1335 - accuracy: 0.9444
# Epoch 134/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2371 - accuracy: 0.9444
# Epoch 135/200
# 4/4 [==============================] - 0s 93ms/step - loss: 0.2115 - accuracy: 0.8889
# Epoch 136/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2470 - accuracy: 0.9444
# Epoch 137/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1621 - accuracy: 0.9444
# Epoch 138/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2177 - accuracy: 0.8889
# Epoch 139/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.1528 - accuracy: 0.9444
# Epoch 140/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2401 - accuracy: 0.8333
# Epoch 141/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9444
# Epoch 142/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1594 - accuracy: 0.9444
# Epoch 143/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1804 - accuracy: 0.9444
# Epoch 144/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1805 - accuracy: 0.9444
# Epoch 145/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2168 - accuracy: 0.9444
# Epoch 146/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1376 - accuracy: 0.9444
# Epoch 147/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1794 - accuracy: 0.9444
# Epoch 148/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2049 - accuracy: 0.9444
# Epoch 149/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1688 - accuracy: 0.9444
# Epoch 150/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1303 - accuracy: 0.9444
# Epoch 151/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2012 - accuracy: 0.9444
# Epoch 152/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2059 - accuracy: 0.9444
# Epoch 153/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2150 - accuracy: 0.9444
# Epoch 154/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1243 - accuracy: 0.9444
# Epoch 155/200
# 4/4 [==============================] - 0s 3ms/step - loss: 0.2133 - accuracy: 0.9444
# Epoch 156/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2404 - accuracy: 0.8889
# Epoch 157/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1751 - accuracy: 0.8889
# Epoch 158/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1821 - accuracy: 0.9444
# Epoch 159/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1521 - accuracy: 0.9444
# Epoch 160/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1820 - accuracy: 0.9444
# Epoch 161/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1924 - accuracy: 0.9444
# Epoch 162/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1561 - accuracy: 0.9444
# Epoch 163/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2420 - accuracy: 0.8889
# Epoch 164/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1360 - accuracy: 0.9444
# Epoch 165/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1572 - accuracy: 0.9444
# Epoch 166/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1777 - accuracy: 0.9444
# Epoch 167/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1737 - accuracy: 0.9444
# Epoch 168/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2593 - accuracy: 0.8889
# Epoch 169/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1859 - accuracy: 0.9444
# Epoch 170/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1748 - accuracy: 0.9444
# Epoch 171/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1332 - accuracy: 0.9444
# Epoch 172/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1467 - accuracy: 0.9444
# Epoch 173/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1719 - accuracy: 0.9444
# Epoch 174/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1295 - accuracy: 0.9444
# Epoch 175/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1445 - accuracy: 0.9444
# Epoch 176/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1039 - accuracy: 0.9444
# Epoch 177/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1308 - accuracy: 0.9444
# Epoch 178/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2291 - accuracy: 0.8889
# Epoch 179/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1532 - accuracy: 0.9444
# Epoch 180/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2298 - accuracy: 0.8889
# Epoch 181/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1487 - accuracy: 0.9444
# Epoch 182/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1969 - accuracy: 0.9444
# Epoch 183/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1136 - accuracy: 0.9444
# Epoch 184/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1777 - accuracy: 0.8889
# Epoch 185/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1162 - accuracy: 0.9444
# Epoch 186/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1154 - accuracy: 0.8889
# Epoch 187/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2091 - accuracy: 0.9444
# Epoch 188/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1934 - accuracy: 0.9444
# Epoch 189/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1406 - accuracy: 0.9444
# Epoch 190/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.1762 - accuracy: 0.9444
# Epoch 191/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1872 - accuracy: 0.9444
# Epoch 192/200
# 4/4 [==============================] - 0s 5ms/step - loss: 0.2174 - accuracy: 0.9444
# Epoch 193/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1573 - accuracy: 0.9444
# Epoch 194/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1409 - accuracy: 0.9444
# Epoch 195/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1289 - accuracy: 0.9444
# Epoch 196/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1537 - accuracy: 0.9444
# Epoch 197/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1883 - accuracy: 0.8889
# Epoch 198/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1412 - accuracy: 0.9444
# Epoch 199/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.1595 - accuracy: 0.9444
# Epoch 200/200
# 4/4 [==============================] - 0s 4ms/step - loss: 0.2118 - accuracy: 0.8889
# Done
# /usr/local/lib/python3.10/dist-packages/keras/src/engine/training.py:3103: UserWarning: You are saving your model as an HDF5 file via `model.save()`. This file format is considered legacy. We recommend using instead the native Keras format, e.g. `model.save('my_model.keras')`.
#   saving_api.save_model(

# %%
import random
import json
import pickle
import numpy as np
import nltk

from nltk.stem import WordNetLemmatizer
from keras.models import load_model

lemmatizer = WordNetLemmatizer()
intents = json.loads(open('/content/intents.json').read())

words = pickle.load(open('words.pkl', 'rb'))
classes = pickle.load(open('classes.pkl', 'rb'))
model = load_model('chatbot_model.h5')


def clean_up_sentence(sentence):
    sentence_words = nltk.word_tokenize(sentence)
    sentence_words = [lemmatizer.lemmatize(word) for word in sentence_words]
    return sentence_words

def bag_of_words (sentence):
    sentence_words = clean_up_sentence(sentence)
    bag = [0] * len(words)
    for w in sentence_words:
        for i, word in enumerate(words):
            if word == w:
                bag[i] = 1
    return np.array(bag)

def predict_class (sentence):
    bow = bag_of_words (sentence)
    res = model.predict(np.array([bow]))[0]
    ERROR_THRESHOLD = 0.25
    results = [[i, r] for i, r in enumerate(res) if r > ERROR_THRESHOLD]

    results.sort(key=lambda x: x[1], reverse=True)
    return_list = []
    for r in results:
        return_list.append({'intent': classes [r[0]], 'probability': str(r[1])})
    return return_list

def get_response(intents_list, intents_json):
    tag = intents_list[0]['intent']
    list_of_intents = intents_json['intents']
    for i in list_of_intents:
        if i['tag'] == tag:
            result = random.choice (i['responses'])
            break
    return result

print("GO! Bot is running!")

while True:
    message = input("")
    ints = predict_class (message)
    res = get_response (ints, intents)
    print (res)
# Out:
# GO! Bot is running!
# hi
# 1/1 [==============================] - 0s 92ms/step
# Good to see you again
# thanks
# 1/1 [==============================] - 0s 20ms/step
# You're Welcome
# thanks
# 1/1 [==============================] - 0s 21ms/step
# My pleasure
# what is python
# 1/1 [==============================] - 0s 19ms/step
# Python is an interpreted, object-oriented, high-level programming language with dynamic semantics. Its high-level built in data structures, combined with dynamic typing and dynamic binding, make it very attractive for Rapid Application Development, as well as for use as a scripting or glue language to connect existing components together
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-1-1c016697ff55> in <cell line: 55>()
#      54
#      55 while True:
# ---> 56     message = input("")
#      57     ints = predict_class (message)
#      58     res = get_response (ints, intents)
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in raw_input(self, prompt)
#     849                 "raw_input was called, but this frontend does not support input requests."
#     850             )
# --> 851         return self._input_request(str(prompt),
#     852             self._parent_ident,
#     853             self._parent_header,
#
# /usr/local/lib/python3.10/dist-packages/ipykernel/kernelbase.py in _input_request(self, prompt, ident, parent, password)
#     893             except KeyboardInterrupt:
#     894                 # re-raise KeyboardInterrupt, to truncate traceback
# --> 895                 raise KeyboardInterrupt("Interrupted by user") from None
#     896             except Exception as e:
#     897                 self.log.warning("Invalid Message:", exc_info=True)
#
# KeyboardInterrupt: Interrupted by user
